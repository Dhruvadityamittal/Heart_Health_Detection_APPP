# %%
import mlflow
from mlflow import MlflowClient

model_name = "RandomForestClassifier"

client = mlflow.tracking.MlflowClient()
client.transition_model_version_stage(
    name=model_name,
    version=1,
    stage="Production"
)

# def fetch_logged_data(run_id):
#     client = MlflowClient()
#     data = client.get_run(run_id).data
#     tags = {k: v for k, v in data.tags.items() if not k.startswith("mlflow.")}
#     artifacts = [f.path for f in client.list_artifacts(run_id, "model")]
#     return data.params, data.metrics, tags, artifacts

# params, metrics, tags, artifacts = fetch_logged_data("cbcdcc792e084eeeb3e7af4be9cf618f")
# Out:
# <ModelVersion: aliases=[], creation_timestamp=1698440283518, current_stage='Production', description=None, last_updated_timestamp=1698440389542, name='RandomForestClassifier', run_id='5ae709bb021340d78733336128153f74', run_link=None, source='file:///C:/Users/Dhruv/OneDrive/Desktop/Personal_Projects/HeartRateDetection/mlruns/529570952684607456/5ae709bb021340d78733336128153f74/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=1>

# %%
from preprocess import get_prepocessed_data
from sklearn.metrics import accuracy_score

# %%
pyfunc_model = mlflow.sklearn.load_model("models:/RandomForestClassifier/Production")

x_train,y_train,x_test,y_test= get_prepocessed_data()

out_train = pyfunc_model.predict(x_train)
accuracy_train = accuracy_score(y_train, out_train)

out_test = pyfunc_model.predict(x_test)
accuracy_test = accuracy_score(y_test, out_test)


print(accuracy_train, accuracy_test)
# Out:
# 1.0 0.8043478260869565

# %%
import pandas as pd

data = pd.read_csv("heart.csv")

# %%
data
# Out:
#      Age Sex ChestPainType  ...  Oldpeak  ST_Slope  HeartDisease
# 0     40   M           ATA  ...      0.0        Up             0
# 1     49   F           NAP  ...      1.0      Flat             1
# 2     37   M           ATA  ...      0.0        Up             0
# 3     48   F           ASY  ...      1.5      Flat             1
# 4     54   M           NAP  ...      0.0        Up             0
# ..   ...  ..           ...  ...      ...       ...           ...
# 913   45   M            TA  ...      1.2      Flat             1
# 914   68   M           ASY  ...      3.4      Flat             1
# 915   57   M           ASY  ...      1.2      Flat             1
# 916   57   F           ATA  ...      0.0      Flat             1
# 917   38   M           NAP  ...      0.0        Up             0
#
# [918 rows x 12 columns]

# %%
data["MaxHR"].unique()
# Out:
# array([172, 156,  98, 108, 122, 170, 142, 130, 120,  99, 145, 140, 137,
#        150, 166, 165, 125, 160, 164, 138, 178, 112, 118, 127, 114, 154,
#        155,  87, 148, 100, 168, 184, 121, 153, 134,  96, 174, 175, 144,
#         82, 135, 115, 128, 116,  94, 110,  92, 180, 152, 124, 106, 185,
#        139, 190, 146, 158, 132, 176, 119, 188, 162, 105,  90, 136, 167,
#        129, 102, 143, 103,  91, 126,  93, 131, 149, 123, 182, 141,  77,
#        109, 133, 179, 113, 104,  95,  72,  97, 117,  86,  63, 157,  83,
#         60,  70, 163,  67,  78,  84, 111,  80, 107, 161,  69,  88,  73,
#        159, 151, 181, 186, 177, 173, 169, 171, 147,  71, 192, 195, 194,
#        187, 202], dtype=int64)
